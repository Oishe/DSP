# %% [markdown]
# <h1><center>Review</center></h1>
#
# \begin{equation*}
# e^{j\theta } =cos( \theta ) \ +\ jsin( \theta )
# \end{equation*}
#
# \begin{equation*}
# \end{equation*}
# \begin{gather*}
# x_{p}( t) =a_{0} \ +\ 2\sum ^{\infty }_{n\ =\ 1}\Bigl[ a_{n} \ cos\left(\tfrac{2\pi nt}{T_{0}}\right) +b_{n} \ sin\left(\tfrac{2\pi nt}{T_{0}}\right)\Bigr]\\
# f_{0} \ =\ \tfrac{1}{T_{0}} \ ;\ fundamental\ frequency\\
# \tfrac{n}{T_{0}} \ \ ;\ n^{th} \ harmonic
# \end{gather*}

# %% [markdown]
# <h1><center>Discrete-time Signals and Systems</center></h1>
#
# ## Delta Function (Unit sample)
# \begin{equation*}
# \delta [n] =\begin{cases}
# 0, & n\neq 0\\
# 1, & n=0
# \end{cases}
# \end{equation*}
# Any signal can be expressed as:
# \begin{equation*}
# 𝑥[𝑛]={\displaystyle \sum^{\infty }_{k=-\infty }} 𝑥[𝑘] \delta [𝑛−𝑘]
# \end{equation*}
#
# ## Unit Step
# \begin{gather*}
# u[n] =\begin{cases}
# 0, & n< 0\\
# 1, & n\geq 0
# \end{cases}\\
# u[n] =\sum ^{\infty }_{k=-\infty } \delta [n-k]
# \end{gather*}
#
# ## Complex Exponential
# \begin{gather*}
# 𝑥[𝑛] =𝐴\alpha ^{n}\\
# 𝑥[𝑛] =|𝐴||\alpha |^{n} 𝑒^{𝑗( \omega_{0} 𝑛+\phi )}
# \end{gather*}
#
# ## Sinusoidal
# ### continuous time
# \begin{gather*}
# 𝑥(𝑡) =𝐴𝑐𝑜𝑠( \varphi _{0} 𝑡+\phi )\\
# 𝑓=\frac{\varphi_{0}}{2\pi } =\frac{1}{T}
# \end{gather*}
# ### discrete time
# \begin{equation*}
# 𝑥[𝑛] =𝐴𝑐𝑜𝑠( \omega _{0} 𝑛+\phi )
# \end{equation*}
#
# ## Periodicity
# ### continous
# \begin{equation*}
# x( t) =( t+T)
# \end{equation*}
# ### discrete
# \begin{equation*}
# x[ n] =x[ n+N]
# \end{equation*}
#
# ## Periodic Discrete Time Sinusoidal
# \begin{gather*}
# x[ n] \ =\ cos( \omega n)\\
# x[ n+N] =cos( \omega n+\omega N) =cos( \omega n) =x[ n]\\
# N=\frac{2\pi k}{\omega } ;N\in \mathbb{Z}
# \end{gather*}
#
# ## Discrete-Time Systems
# \begin{equation*}
# y[ n] =T\{x[ n]\}
# \end{equation*}
# ![DiscreteTimeSystems.png](./images/DiscreteTimeSystems.png)
#
# ### Properties of LTI
# #### Distributive
# \begin{equation*}
# 𝑥[ 𝑛] \ast h_{1}[ 𝑛] +h_{2}[ 𝑛] =𝑥[ 𝑛] \ast h_{1}[ 𝑛] +𝑥[ 𝑛] \ast h_{2} \ [ 𝑛]
# \end{equation*}
# ![LTIDistributive](./images/LTIDistributive.png)
#
# #### Associative and Commutative
# \begin{equation*}
# ( 𝑥[ 𝑛] \ast h_{1}[ 𝑛]) \ast h_{2}[ 𝑛] =𝑥[ 𝑛] \ast ( h_{1}[ 𝑛] \ast h_{2}[ 𝑛])
# \end{equation*}
# ![LTIAssociative](./images/LTIAssociative.png)
#
#
#
#
# ### Linear Constant Coefficient Difference Equations
#
# \begin{gather*}
# \sum ^{N}_{k=0} \ a_{k} \ y[ n-k] =\sum ^{M}_{k=0} \ b_{k} \ x[ n-k]\\
# y[ n] =\frac{1}{a_{0}}\left( -\sum ^{N}_{k=1} \ a_{k} \ y[ n-k] +\sum ^{M}_{k=0} \ b_{k} \ x[ n-k]\right)
# \end{gather*}
#
# ## Frequency-Domain Representation of Discrete-Time signals and Systems
#
# ### LTI I/O unit pulse gives impluse response
#
# \begin{equation*}
# \delta [ n] \ \rightarrow h[ n]
# \end{equation*}
# ### LTI frequency response I/O eigenfunction
# \begin{gather*}
# x[ n] =e^{j\omega n}\\
# y[ n] =H\left( e^{j\omega }\right) e^{j\omega n}\\
# H\left( e^{j\omega }\right) \ =\ \sum ^{\infty }_{k=-\infty } h[ k] e^{-j\omega k}
# \end{gather*}
# ## Frequency response of LTW is DTFT of impulse response
# ### Properties
#
# \begin{equation*}
# nx[ n] \leftrightarrow j\frac{dX\left( e^{j\omega }\right)}{d\omega }
# \end{equation*}
#
# \begin{gather*}
# y[ n] \ =\ x[ n] *h[ n]\\
# Y\left( e^{j\omega }\right) =X\left( e^{j\omega }\right) H\left( e^{j\omega }\right)
# \end{gather*}
#
# ### Windowing Theorem
#
# \begin{gather*}
# y[ n] =x[ n] w[ n]\\
# Y\left( e^{j\omega }\right) =\frac{1}{2\pi }\int ^{\pi }_{-\pi } X\left( e^{j\theta }\right) W\left( e^{j( \omega -\theta )}\right) d\theta
# \end{gather*}
#
# ## INSERT FOURIER TRANSFORM PAIRS AND THEOREMS (1:53-54)
# Periodic Sampling
#
# \begin{gather*}
# x[ n] =x_{c}( nT)\\
# f_{s} \ =\ \frac{1}{T}\\
# \text{Impulse train}\\
# s( t) \ =\ \sum ^{\infty }_{n=-\infty } \delta ( t-nT)\\
# x_{s}( t) \ =\ x_{c}( t) s( t) \ =\sum ^{\infty }_{n=-\infty } x_{c}( t) \delta ( t-nT)\\
# S( j\Omega ) =\frac{2\pi }{T}\sum ^{\infty }_{k=-\infty } \delta ( \Omega -k\Omega _{s})\\
# \Omega _{s} =\frac{2\pi }{T} \ \text{rads/sec}\\
# X_{s}( j\Omega ) \ =\frac{1}{T}\sum ^{\infty }_{k=-\infty } X_{c}{\displaystyle (} j( \Omega -k\Omega _{s}))\\
# \text{Nyquist}\\
# \Omega _{s} =\frac{2\pi }{T} \geq 2\Omega _{n} \
# \end{gather*}
#
# \begin{equation*}
# X\left( e^{j\omega }\right) =\frac{1}{T}\sum ^{\infty }_{k=-\infty } X_{c}\left[ j\left(\frac{\omega }{T} -\frac{2\pi k}{T}\right)\right]
# \end{equation*}
